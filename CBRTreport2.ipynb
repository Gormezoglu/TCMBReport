# %%
from evds import evdsAPI
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import seaborn as sns
import keys

# %%
# !pip install evds
# Out:
# Collecting evds
#   Downloading evds-0.3.1-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: pandas in c:\users\samsung\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from evds) (1.5.2)
# Requirement already satisfied: requests in c:\users\samsung\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from evds) (2.28.2)
# Requirement already satisfied: urllib3 in c:\users\samsung\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from evds) (1.26.14)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\samsung\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->evds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samsung\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->evds) (2022.6)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\samsung\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->evds) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\samsung\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->evds) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samsung\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->evds) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samsung\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->evds) (2022.12.7)
# Requirement already satisfied: six>=1.5 in c:\users\samsung\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.1->pandas->evds) (1.16.0)
# Installing collected packages: evds
# Successfully installed evds-0.3.1

# %%
key_cbrt = keys.CBRT_API_KEY

# %%
today = datetime.today().strftime('%d-%m-%Y')
print(today)
# Out:
# 11-07-2023

# %%
evds = evdsAPI(key_cbrt)

df = pd.DataFrame(data = evds.get_data(['TP.DK.USD.A.YTL','TP.DK.EUR.A.YTL'], startdate="01-01-2016", enddate=today))

df_dropped = df.dropna()

df_dropped_rev = df_dropped[::-1]

df_dropped_rev
# Out:
#            Tarih  TP_DK_USD_A_YTL  TP_DK_EUR_A_YTL
# 2748  11-07-2023          26.0564          28.5515
# 2747  10-07-2023          26.0381          28.3370
# 2744  07-07-2023          26.0452          28.3161
# 2743  06-07-2023          26.0474          28.3518
# 2742  05-07-2023          26.0035          28.3464
# ...          ...              ...              ...
# 7     08-01-2016           3.0167           3.2688
# 6     07-01-2016           3.0040           3.2255
# 5     06-01-2016           2.9750           3.2061
# 4     05-01-2016           2.9422           3.2116
# 3     04-01-2016           2.9181           3.1838
#
# [1888 rows x 3 columns]

# %%
plt.plot(df_dropped['Tarih'],df_dropped['TP_DK_USD_A_YTL'])
plt.xlabel("Tarih")
plt.ylabel("Kur")
plt.title('USDTRY Kuru')

t= df_dropped['Tarih']
s= df_dropped['TP_DK_USD_A_YTL']


fig, ax = plt.subplots()
ax.plot(t, s)

ax.xaxis.grid(True, which='major')

ax.xaxis.set_major_locator(MultipleLocator(360))


ax.xaxis.set_minor_locator(MultipleLocator(30))




plt.show()
